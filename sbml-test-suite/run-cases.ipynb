# %%
cases = ['00001','00002','00003']

# %%
# %cd ~/devel/src/tellurium-combine-archive-test-cases/sbml-test-suite
# Out:
# /home/poltergeist/devel/src/tellurium-combine-archive-test-cases/sbml-test-suite

# %%
import tellurium as te
import os

lv_string = 'l3v1'
lv_archive_path = os.path.join('archives', lv_string)
for case in cases:
    archive_name = case+'.omex'
    print('Running {}'.format(archive_name))
    case_path = os.path.join(lv_archive_path, archive_name)
    csv = te.extractFileFromCombineArchive(case_path, case+'-results.csv')
    from io import StringIO
    import pandas as pd
    df = pd.read_csv(StringIO(csv))
    report = te.getLastReport()
    report = report.drop(report.shape[0]-1)
    print(df)
    te.convertAndExecuteCombineArchive(case_path)

# %%
report = te.getLastReport()
report.drop(report.shape[0]-1)
# Out:
#     time  S1*compartment_  S2*compartment_
# 0    0.0         0.015000         0.000000
# 1    0.1         0.013573         0.002855
# 2    0.2         0.012281         0.005438
# 3    0.3         0.011112         0.007775
# 4    0.4         0.010055         0.009890
# 5    0.5         0.009098         0.011804
# 6    0.6         0.008232         0.013536
# 7    0.7         0.007449         0.015102
# 8    0.8         0.006740         0.016520
# 9    0.9         0.006099         0.017803
# 10   1.0         0.005518         0.018964
# 11   1.1         0.004993         0.020014
# 12   1.2         0.004518         0.020964
# 13   1.3         0.004088         0.021824
# 14   1.4         0.003699         0.022602
# 15   1.5         0.003347         0.023306
# 16   1.6         0.003028         0.023943
# 17   1.7         0.002740         0.024519
# 18   1.8         0.002479         0.025041
# 19   1.9         0.002244         0.025513
# 20   2.0         0.002030         0.025940
# 21   2.1         0.001837         0.026326
# 22   2.2         0.001662         0.026676
# 23   2.3         0.001504         0.026992
# 24   2.4         0.001361         0.027278
# 25   2.5         0.001231         0.027537
# 26   2.6         0.001114         0.027772
# 27   2.7         0.001008         0.027984
# 28   2.8         0.000912         0.028176
# 29   2.9         0.000825         0.028349
# 30   3.0         0.000747         0.028506
# 31   3.1         0.000676         0.028648
# 32   3.2         0.000611         0.028777
# 33   3.3         0.000553         0.028893
# 34   3.4         0.000501         0.028999
# 35   3.5         0.000453         0.029094
# 36   3.6         0.000410         0.029180
# 37   3.7         0.000371         0.029258
# 38   3.8         0.000336         0.029329
# 39   3.9         0.000304         0.029393
# 40   4.0         0.000275         0.029451
# 41   4.1         0.000249         0.029503
# 42   4.2         0.000225         0.029550
# 43   4.3         0.000204         0.029593
# 44   4.4         0.000184         0.029632
# 45   4.5         0.000167         0.029667
# 46   4.6         0.000151         0.029698
# 47   4.7         0.000136         0.029727
# 48   4.8         0.000123         0.029753
# 49   4.9         0.000112         0.029777
# 50   5.0         0.000101         0.029798
